# %% [markdown]
# # Donald Bango
# # Probabilistic Classifier with Naive Bayes
# # Twitter US Airline Sentiment
# # 3 April 2024
# # Dr. Aiman Darwiche

# %% [markdown]
# # US Airline Sentiment Dataset
#
# **Title**: Twitter US Airline Sentiment
# **Source**: Available for download from Kaggle
# **Link**: https://www.kaggle.com/datasets/crowdflower/twitter-airline-sentiment
# **License**: CC BY-NC-SA 4.0
# **Date of Dataset**: Tweets collected February 2015
#
# **Description**:
# The Twitter US Airline Sentiment dataset comprises tweets related to major US airlines, capturing user experiences and sentiments. The data is classified into positive, negative, or neutral sentiments, providing a valuable resource for understanding public perception of airline services.
#
# **Content**:
# The dataset includes various features such as sentiment confidence scores, Twitter user IDs, reasons for negative sentiments, airline names, retweet counts, tweet text, timestamps, location, and tweet coordinates. Specifically, it categorizes tweets with sentiments and identifies negative reasons like "late flight" or "rude service".
#
# **Usage**:
# The data was originally compiled by Crowdflower for their "Data for Everyone" library, instrumental for companies and researchers looking to analyze customer feedback on social media. By examining the sentiment of tweets, businesses can gain insights into areas requiring improvement and gain a better understanding of customer needs.
#
# **License Details**:
# The dataset is shared under the Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License, allowing for sharing and for non-commercial purposes, provided that appropriate credit is given and any changes are distributed under the same license.

# %% [markdown]
# # Dataset's Origin and Ethical Considerations
#
# The Twitter US Airline Sentiment dataset, assembled by Crowdflower (now Figure Eight) and available on Kaggle, captures public opinions of US airlines from tweets since February 2015. It operates under the Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International (CC BY-NC-SA 4.0) license, promoting ethical use by crediting creators and ensuring adaptations share the same license. This ensures respect for user privacy by focusing on public tweets without exposing private information.
#
# However, the dataset's reliance on social media data introduces potential biases, such as differing sentiment expressions among demographic groups and the varying likelihood of tweeting positive or negative experiences. The dataset does not anonymize Twitter usernames. Overall, the collection process was deemed ethical because the information included was already made public, and users had the choice to keep their tweets private.

# %% [markdown]
# # Attribute Information of the Twitter US Airline Sentiment Dataset
#
# - **Airline Sentiment**: Categorical, indicating the sentiment of the tweet (Positive, Neutral, Negative).
# - **Sentiment Confidence Score**: Continuous, representing the confidence level of the assigned sentiment.
# - **Negative Reason**: Categorical, specifying the reason for negative sentiments (e.g., "Late Flight", "Rude Service"), applicable only for negative sentiment tweets.
# - **Airline**: Categorical, names of the US airlines to which the tweets are directed.
# - **Retweet Count**: Continuous, the number of retweets for each tweet, indicating its viral nature or reach.
# - **Tweet Text**: Text, the content of the user’s tweet, expressing their opinion or experience.
# - **Tweet Coordinates**: Geographical coordinates from which the tweet was sent (if available).
# - **Date and Time of Tweet**: Timestamp, when the tweet was posted, providing temporal context to the sentiment.
# - **Location of Tweet**: Text, the user’s stated geographical location as provided in the tweet (if available).
# - **Twitter ID**: Identifier, unique ID for each tweet, allowing for precise referencing.

# %% [markdown]
# # Explanation of the Dataset
#
# The Twitter US Airline Sentiment dataset compiles tweets from February 2015, classifying them into positive, negative, and neutral sentiments to reflect public opinions toward major US airlines. By including sentiment scores, reasons for negative sentiments (e.g., "late flight" or "rude service"), and airline names, it provides a detailed resource for sentiment analysis. The dataset aims to analyze and predict public sentiment on airline services, providing insights through sentiment confidence scores and textual content.
#
# It facilitates deeper analysis of customer sentiment by identifying trends and pinpointing improvement areas in airline services. By analyzing these tweets, researchers can observe public opinion trends and the effects of specific events on customer satisfaction. Ultimately, it serves as a tool for understanding customer service, public relations, and brand perception in the airline industry.

# %% [markdown]
# # Objectives for Applying Classification Methods to the Twitter US Airline Sentiment Dataset
#
# Our project aims to employ the Naive Bayes classifier for sentiment analysis on the Twitter US Airline Sentiment dataset. This probabilistic classifier is chosen for its effectiveness in handling text data, simplicity, and its foundation in probability theory, which is well-suited for text classification tasks such as sentiment analysis. Here are our primary objectives:
#
# - **Classify Sentiment**: The primary goal is to accurately categorize tweets into positive, negative, or neutral sentiments using the Naive Bayes algorithm. This task leverages the probabilistic nature of Naive Bayes to make predictions based on the text's features, considering the probabilities of words occurring in positive, negative, or neutral contexts.
#
# - **Analyze Sentiment Trends**: Beyond mere classification, we aim to analyze sentiment trends over time and across different airlines. This involves observing how sentiment distribution varies and identifying potential triggers for sentiment shifts, such as specific events or service changes. This analysis will provide deeper insights into customer sentiment dynamics.
#
# - **Guide Customer Service Improvements**: The insights gained from sentiment classification can inform airlines and stakeholders about strengths and weaknesses in customer service. Identifying common themes in negative sentiments, for example, "late flights" or "rude service," can guide targeted improvements.
#
# - **Enhance Understanding of Public Perception**: Through this analysis, we seek to contribute to a broader understanding of public perception towards airline services. By quantifying and categorizing sentiments expressed on Twitter, we can gauge overall customer satisfaction and identify areas for enhancement in the airline industry.
#
# To achieve these objectives:
#
# 1. Choose the appropriate Naive Bayes model variant (Gaussian, Multinomial, or Bernoulli) based on the data’s characteristics and our analysis needs, primarily focusing on text data vectorization requirements.
# 2. Perform EDA and data preprocessing steps including text normalization and feature scaling (if applicable) to prepare the dataset for analysis.
# 3. Vectorize the tweet text into numerical values, an essential step for text analysis allowing the Naive Bayes algorithm to process and classify the textual data effectively.
# 4. Train the Naive Bayes classifier on the training set and make sentiment predictions on unseen data.
# 5. Validate the model's performance using various metrics such as accuracy, confusion matrix, ROC-AUC curves, and k-fold cross-validation, to ensure reliability and robustness of our sentiment analysis.
#
# By fulfilling these objectives, we leverage the Naive Bayes classifier to provide insights that guide informed decisions regarding airline customer sentiment, offering a resource for enhancing service quality and understanding customer needs.

# %% [markdown]
# # The Naive Bayes Algorithm and Its Application
#
# The Naive Bayes classifier is a probabilistic machine learning model used for sentiment analysis, valued for its simplicity and efficiency in dealing with large datasets of textual data.
#
# **Principle**: Naive Bayes applies Bayes’ theorem under the assumption that each feature (word) is conditionally independent of every other feature. While this independence assumption is rarely true in natural language, Naive Bayes often performs remarkably well for text classification because this simplified model still captures enough relevant structure for accurate predictions.
#
# **Model Selection**: Given the textual nature of our dataset, we plan to employ the **Multinomial Naive Bayes** variant. This choice is driven by the algorithm’s suitability for discrete features (such as word counts or frequencies) produced after vectorizing tweets. Multinomial Naive Bayes is particularly adept at handling frequency data, aligning well with the requirements of this classification task.
#
# **Key Considerations for Naive Bayes**:
# - **Assumption of Independence**: Although not strictly valid for natural language (where words can be highly correlated), the model’s performance in text classification remains surprisingly robust.
# - **Data Preprocessing**: Effective text preprocessing—such as tokenization, removing stop words, and optionally stemming or lemmatization—is essential to reduce dimensionality and focus on the most informative aspects of the text.
#
# By employing the Naive Bayes classifier, the aim is to categorize tweets into positive, negative, or neutral sentiments accurately. This analysis will help us gauge public sentiment toward various airlines, providing insights into both existing strengths and opportunities for improvement in customer feedback.

# %% [markdown]
# # Key Questions for Sentiment Analysis Using Naive Bayes
#
# 1. **Can the Naive Bayes classifier precisely classify tweets into positive, negative, or neutral sentiments regarding US airlines?**
#    We aim to assess how effectively Naive Bayes can categorize tweets based on their textual content, highlighting the efficiency of its probabilistic approach in sentiment analysis.
#
# 2. **How do specific keywords or phrases affect the sentiment classification of tweets about airlines?**
#    This question examines the role of language in sentiment analysis, exploring whether certain words strongly indicate sentiment and how Naive Bayes uses these features for classification in airline-related contexts.

# %%
# Imports
import warnings
warnings.filterwarnings("ignore")

import re
import nltk
from nltk.corpus import stopwords

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from wordcloud import WordCloud, STOPWORDS

# Required for HalvingGridSearchCV
from sklearn.experimental import enable_halving_search_cv

# Scikit-Learn imports
from sklearn.model_selection import train_test_split, HalvingGridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import BernoulliNB, GaussianNB, MultinomialNB, ComplementNB
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.naive_bayes import BernoulliNB, GaussianNB, MultinomialNB, ComplementNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score, ConfusionMatrixDisplay,classification_report

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Import dataset
# Link: https://www.kaggle.com/datasets/crowdflower/twitter-airline-sentiment
data = pd.read_csv('/Users/don/Downloads/Tweets.csv')

# %% [markdown]
# # Exploratory Data Analysis and Data Preprocessing
#
# - inspect the data's shape, missing values, duplicates, etc.

# %%
# Display the first 5 rows
data.head(5)
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
# Display the last 5 rows
data.tail(5)
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 14635  569587686496825344          positive                        0.3487
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence   airline  \
# 14635                     NaN                     0.0000  American
# 14636  Customer Service Issue                     1.0000  American
# 14637                     NaN                        NaN  American
# 14638  Customer Service Issue                     0.6659  American
# 14639                     NaN                     0.0000  American
#
#       airline_sentiment_gold             name negativereason_gold  \
# ...

# %%
print(data.shape)
# Out:
# (14640, 15)

# %%
# Shows data types and non-null counts for each column
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      14640 non-null  int64
#  1   airline_sentiment             14640 non-null  object
#  2   airline_sentiment_confidence  14640 non-null  float64
#  3   negativereason                9178 non-null   object
#  4   negativereason_confidence     10522 non-null  float64
#  5   airline                       14640 non-null  object
#  6   airline_sentiment_gold        40 non-null     object
#  7   name                          14640 non-null  object
#  8   negativereason_gold           32 non-null     object
#  9   retweet_count                 14640 non-null  int64
#  10  text                          14640 non-null  object
#  11  tweet_coord                   1019 non-null   object
# ...

# %%
print(data.describe())
# Out:
#            tweet_id  airline_sentiment_confidence  negativereason_confidence  \
# count  1.464000e+04                  14640.000000               10522.000000
# mean   5.692184e+17                      0.900169                   0.638298
# std    7.791112e+14                      0.162830                   0.330440
# min    5.675883e+17                      0.335000                   0.000000
# 25%    5.685592e+17                      0.692300                   0.360600
# 50%    5.694779e+17                      1.000000                   0.670600
# 75%    5.698905e+17                      1.000000                   1.000000
# max    5.703106e+17                      1.000000                   1.000000
#
#        retweet_count
# count   14640.000000
# mean        0.082650
# std         0.745778
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        44.000000

# %%
# Checking for missing/null values
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# tweet_id                            0
# airline_sentiment                   0
# airline_sentiment_confidence        0
# negativereason                   5462
# negativereason_confidence        4118
# airline                             0
# airline_sentiment_gold          14600
# name                                0
# negativereason_gold             14608
# retweet_count                       0
# text                                0
# tweet_coord                     13621
# tweet_created                       0
# tweet_location                   4733
# user_timezone                    4820
# dtype: int64

# %%
# Percentage null or na values in df
missing_percent = ((data.isnull() | data.isna()).sum() * 100 / data.index.size).round(2)
print(missing_percent)
# Out:
# tweet_id                         0.00
# airline_sentiment                0.00
# airline_sentiment_confidence     0.00
# negativereason                  37.31
# negativereason_confidence       28.13
# airline                          0.00
# airline_sentiment_gold          99.73
# name                             0.00
# negativereason_gold             99.78
# retweet_count                    0.00
# text                             0.00
# tweet_coord                     93.04
# tweet_created                    0.00
# tweet_location                  32.33
# user_timezone                   32.92
# dtype: float64

# %%
# Checking for duplicate entries in the dataset
duplicates = data.duplicated()
print(f"Number of duplicate entries: {duplicates.sum()}")
# Out:
# Number of duplicate entries: 36

# %%
duplicate_rows = data[data.duplicated(keep=False)]
duplicate_rows
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 11879  570308309682675712          negative                           1.0
# 11898  570305051819941889           neutral                           1.0
# 11902  570303383782989824           neutral                           1.0
# 11905  570301929580048385           neutral                           1.0
# 11907  570301395141836801          negative                           1.0
# ...                   ...               ...                           ...
# 12155  570275010759102466          negative                           1.0
# 12157  570273819287531520          positive                           1.0
# 12158  570273710210469888          positive                           1.0
# 12159  570272880556011520          positive                           1.0
# 12162  570272018840428544           neutral                           1.0
#
#                negativereason  negativereason_confidence   airline  \
# ...

# %% [markdown]
# Outliers do not apply to the subsequent text analysis.

# %%
# Number of unique values
data.nunique()
# Out:
# tweet_id                        14485
# airline_sentiment                   3
# airline_sentiment_confidence     1023
# negativereason                     10
# negativereason_confidence        1410
# airline                             6
# airline_sentiment_gold              3
# name                             7701
# negativereason_gold                13
# retweet_count                      18
# text                            14427
# tweet_coord                       832
# tweet_created                   14247
# tweet_location                   3081
# user_timezone                      85
# dtype: int64

# %%
data['airline_sentiment'].value_counts()
# Out:
# negative    9178
# neutral     3099
# positive    2363
# Name: airline_sentiment, dtype: int64

# %%
plt.figure(figsize=(4, 3))
sns.countplot(x=data['airline_sentiment'])
plt.title("Distribution of Airline Sentiment")
plt.xlabel("Sentiment")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Data Preprocessing

# %%
# Convert 'tweet_created' to datetime format and extract only the date component
data['tweet_created'] = pd.to_datetime(data['tweet_created']).dt.date

# Convert 'tweet_created' back to full datetime format for consistent datetime operations
data['tweet_created'] = pd.to_datetime(data['tweet_created'])

# Check updated info after date conversion
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      14640 non-null  int64
#  1   airline_sentiment             14640 non-null  object
#  2   airline_sentiment_confidence  14640 non-null  float64
#  3   negativereason                9178 non-null   object
#  4   negativereason_confidence     10522 non-null  float64
#  5   airline                       14640 non-null  object
#  6   airline_sentiment_gold        40 non-null     object
#  7   name                          14640 non-null  object
#  8   negativereason_gold           32 non-null     object
#  9   retweet_count                 14640 non-null  int64
#  10  text                          14640 non-null  object
#  11  tweet_coord                   1019 non-null   object
# ...

# %%
# Checking Date Range

print("Earliest tweet:", data['tweet_created'].min())
print("Latest tweet :", data['tweet_created'].max())
print("Number of unique dates:", data['tweet_created'].nunique())
# Out:
# Earliest tweet: 2015-02-16 00:00:00
# Latest tweet : 2015-02-24 00:00:00
# Number of unique dates: 9

# %% [markdown]
# The data spans 9 days in 2015, specifically february 16th 2015 to february 24th 2015

# %%
# Tweet Volume by Day
numberoftweets = data.groupby('tweet_created').size()
print(numberoftweets)
# Out:
# tweet_created
# 2015-02-16       4
# 2015-02-17    1408
# 2015-02-18    1344
# 2015-02-19    1376
# 2015-02-20    1500
# 2015-02-21    1557
# 2015-02-22    3079
# 2015-02-23    3028
# 2015-02-24    1344
# dtype: int64

# %% [markdown]
# The volume of tweets shows significant variation over the period:
# - Minimal tweets recorded on Feb 16th (only 4).
# - Over 3,000 tweets on Feb 22nd & 23rd, indicating a spike in public interest.
#
# The data starts with a minimal count of only 4 tweets on February 16th, but sees a substantial increase to over 1,400 tweets by February 17th, maintaining a relatively stable volume through February 21st. A notable spike occurs on February 22nd and 23rd, where the tweet volume more than doubles, reaching over 3,000 tweets each day, indicating a peak in public interest or reaction to airline-related events during these dates. The volume then drops back to around 1,344 tweets on February 24th, suggesting the conversation or event that caused the spike had subsided.

# %% [markdown]
# # Handling missing values
# The dataset contains missing values in columns that do not affect our Naive Bayes text feature or the target variable.
# The missing values do not affect our model's performance or results. There is no need to drop them.

# %%
# Count the number of occurrences for each negative reason
freq = data.groupby('negativereason').size()
print("Count of each negative reason:")
print(freq)
# Out:
# Count of each negative reason:
# negativereason
# Bad Flight                      580
# Can't Tell                     1190
# Cancelled Flight                847
# Customer Service Issue         2910
# Damaged Luggage                  74
# Flight Attendant Complaints     481
# Flight Booking Problems         529
# Late Flight                    1665
# Lost Luggage                    724
# longlines                       178
# dtype: int64

# %% [markdown]
# A majority of negative tweets pertain to negative customer service experiences and Late Flights.

# %%
# Unique Airlines in the Dataset
unique_airlines = data['airline'].unique()
print("Airlines in dataset:", unique_airlines)
# Out:
# Airlines in dataset: ['Virgin America' 'United' 'Southwest' 'Delta' 'US Airways' 'American']

# %%
# Sentiment by Airline Company
print("Total number of tweets for each airline \n ",data.groupby('airline')['airline_sentiment'].count().sort_values(ascending = False))
# Out:
# Total number of tweets for each airline
#   airline
# United            3822
# US Airways        2913
# American          2759
# Southwest         2420
# Delta             2222
# Virgin America     504
# Name: airline_sentiment, dtype: int64

# %%
# Bar Charts of Sentiment by Airline
airlines= ['US Airways','United','American','Southwest','Delta','Virgin America']
plt.figure(1,figsize=(12, 12))
for i in airlines:
    indices= airlines.index(i)
    plt.subplot(2,3,indices+1)
    new_df=data[data['airline']==i]
    count=new_df['airline_sentiment'].value_counts()
    Index = [1,2,3]
    plt.bar(Index,count, color=['red', 'green', 'blue'])
    plt.xticks(Index,['negative','neutral','positive'])
    plt.ylabel('Mood Count')
    plt.xlabel('Mood')
    plt.title('Count of Moods of '+i)

# %% [markdown]
# A majority of tweets consist of negative sentiment regarding the airline the customer had an experience with. This might be the result of human nature to only tweet about negative experiences with companies and not the positive experiences with their carrier.

# %%
# Calculating Percentage of Negative Tweets
neg_tweets = data.groupby(['airline','airline_sentiment']).count().iloc[:,0]
total_tweets = data.groupby(['airline'])['airline_sentiment'].count()

my_dict = {'American':neg_tweets[0] / total_tweets[0],'Delta':neg_tweets[3] / total_tweets[1],'Southwest': neg_tweets[6] / total_tweets[2],
'US Airways': neg_tweets[9] / total_tweets[3],'United': neg_tweets[12] / total_tweets[4],'Virgin': neg_tweets[15] / total_tweets[5]}
perc = pd.DataFrame.from_dict(my_dict, orient = 'index')
perc.columns = ['Percent Negative']
print(perc)
ax = perc.plot(kind = 'bar', rot=0, colormap = 'Spectral', figsize = (15,6))
ax.set_xlabel('Airlines')
ax.set_ylabel('Percentage of negative tweets')
plt.show()
# Out:
#             Percent Negative
# American            0.710402
# Delta               0.429793
# Southwest           0.490083
# US Airways          0.776862
# United              0.688906
# Virgin              0.359127

# %% [markdown]
# US Airways, United, and American airlines receive notably more negative feedback, whereas Virgin America's tweets are more evenly distributed across sentiments.

# %%
# Stacked Bar Chart of Sentiment Distribution
# Group by airline and sentiment, then get counts
airline_sent = data.groupby(['airline', 'airline_sentiment']).size()

# Convert the result into a DataFrame with sentiments as columns
sentiment_unstacked = airline_sent.unstack()

# Plot a stacked bar chart
sentiment_unstacked.plot(kind='bar', stacked=True, figsize=(15, 10))

plt.title("Stacked Bar Chart of Airline Sentiment Distribution")
plt.xlabel("Airline")
plt.ylabel("Number of Tweets")
plt.legend(title="Sentiment", loc="upper right")
plt.tight_layout()
plt.show()

# %%
# Print grouped airline_sent
print("Airline sentiment counts:\n")
print(airline_sent)
# Out:
# Airline sentiment counts:
#
# airline         airline_sentiment
# American        negative             1960
#                 neutral               463
#                 positive              336
# Delta           negative              955
#                 neutral               723
#                 positive              544
# Southwest       negative             1186
#                 neutral               664
#                 positive              570
# US Airways      negative             2263
#                 neutral               381
#                 positive              269
# United          negative             2633
#                 neutral               697
#                 positive              492
# Virgin America  negative              181
#                 neutral               171
#                 positive              152
# dtype: int64

# %%
# Distribution of complaints by airline
negative_reasons = data.groupby('airline')['negativereason'].value_counts(ascending=True)

# We group by (airline, negativereason), then unstack to create columns for each reason
negative_reasons.groupby(['airline','negativereason']).sum().unstack().plot(kind='bar',figsize=(22,12))
plt.xlabel('Airline Company')
plt.ylabel('Number of Negative reasons')
plt.title("The number of the count of negative reasons for airlines")
plt.show()

# %% [markdown]
# Again, the bar chart confirms that for US Airways, United, American, Southwest, and Virgin America, the predominant cause of complaints is customer service issues, whereas late flights are the primary concern for Delta. Virgin America stands out for having the fewest complaints by percentage, with all negative reasons tallying less than 40% of overall tweets. Virgin America has the most balanced sentiment but also the least tweets relating to their services.

# %%
# Overall Counts of Negative Reasons
reason_counts = data['negativereason'].value_counts()

# Counts of complaint reasons for the whole dataset
plt.figure(figsize=(10, 6))
reason_counts.plot(kind='bar', color='skyblue')
plt.title('Overall Counts of Reasons for Complaints')
plt.xlabel('Reason for Complaint')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
#Negative Tweets by Day and Airline
day_df = day_df.loc(axis=0)[:,:,'negative']

#groupby and plot data
ax2 = day_df.groupby(['tweet_created','airline']).sum().unstack().plot(kind = 'bar', color=['red', 'green', 'blue','yellow','purple','orange'], figsize = (15,6), rot = 70)
labels = ['American','Delta','Southwest','US Airways','United','Virgin America']
ax2.legend(labels = labels)
ax2.set_xlabel('Date')
ax2.set_ylabel('Negative Tweets')
plt.show()

# %% [markdown]
# On February 22nd and 23rd, 2015, American Airlines saw a significant increase in negative tweets, which halved by the next day, indicating a resolution to customer service issues or a lower volume of flights. Virgin America had the fewest negative tweets, correlating with its lower overall tweet volume.

# %%
# Positive Word Cloud
new_df = data[data['airline_sentiment']=='positive']
words = ' '.join(new_df['text'])
cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and word != 'RT'
                            ])
wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=3000,
                      height=2500
                     ).generate(cleaned_word)
plt.figure(1,figsize=(12, 12))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# Neutral WordCloud

new_df=data[data['airline_sentiment']=='neutral']
words = ' '.join(new_df['text'])
cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and word != 'RT'
                            ])
wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=3000,
                      height=2500
                     ).generate(cleaned_word)
plt.figure(1,figsize=(12, 12))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# Negative Wordcloud

new_df=data[data['airline_sentiment']=='negative']
words = ' '.join(new_df['text'])
cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and word != 'RT'
                            ])
wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=3000,
                      height=2500
                     ).generate(cleaned_word)
plt.figure(1,figsize=(12, 12))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# The 'negative' word cloud highlights some of the issues customers face that relate to their negative experience they have tweeted about.
# A couple notable words pertaint to time like hold and wait  and you also notice words like delay, cancelled, and help.

# %%
# Creating a new dataframe with only the text feature and airline_sentiment.
df = data[['text','airline_sentiment']]
df.head(5)
# Out:
#                                                 text airline_sentiment
# 0                @VirginAmerica What @dhepburn said.           neutral
# 1  @VirginAmerica plus you've added commercials t...          positive
# 2  @VirginAmerica I didn't today... Must mean I n...           neutral
# 3  @VirginAmerica it's really aggressive to blast...          negative
# 4  @VirginAmerica and it's a really big bad thing...          negative

# %%
# Check for missing values
print(df.isna().sum())
# Out:
# text                 0
# airline_sentiment    0
# dtype: int64

# %%
# Print initial shape
print(df.shape)
# Out:
# (14640, 2)

# %%
# Identifying duplicated entries
print(df.duplicated().sum())
# Out:
# 188

# %%
# Dropping duplicated entries
df = df.drop_duplicates()

# Verification of dropped data
df.duplicated().sum()
# Out:
# 0

# %%
# Final shape

df.shape
# Out:
# (14640, 2)

# %%
# Cleaning tweet text by removing special characters for readability

# Function to Clean Tweet Text
def clean_text(text):
    '''Cleans the input text by applying several regex operations:
        1. Converts to lowercase.
        2. Removes bracketed text.
        3. Strips out URLs.
        4. Removes HTML tags.
        5. Eliminates punctuation.
        6. Removes newline characters.
        7. Drops words containing digits.
'''
    text = str(text).lower() # convert text to lowercase
    text = re.sub('\[.*?\]', '', text) 
    text = re.sub(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?', '', text) # Remove URl and tags
    text = re.sub('<.*?>+', '', text)
    text = re.sub(r'[^a-z0-9\s]', '', text) # Remove punctuation
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
# Apply cleaning to the 'text' column
df['text'] = df['text'].apply(clean_text)

# %%
# Preview the first 5 cleaned tweets
df['text'].head(5)
# Out:
# 0                     virginamerica what dhepburn said
# 1    virginamerica plus youve added commercials to ...
# 2    virginamerica i didnt today must mean i need t...
# 3    virginamerica its really aggressive to blast o...
# 4    virginamerica and its a really big bad thing a...
# Name: text, dtype: object

# %%
# Split data into features (X) and target (y)
X = df['text']                # The cleaned tweet text
y = df['airline_sentiment']   # The sentiment label (negative, neutral, positive)

print("Feature sample:\n", X.head(3))
print("\nLabel sample:\n", y.head(3))
# Out:
# Feature sample:
#  0                     virginamerica what dhepburn said
# 1    virginamerica plus youve added commercials to ...
# 2    virginamerica i didnt today must mean i need t...
# Name: text, dtype: object
#
# Label sample:
#  0     neutral
# 1    positive
# 2     neutral
# Name: airline_sentiment, dtype: object

# %%
# Train-Test Split
# We'll use an 80/20 split, where 80% of the data is for training and 20% for testing.
# The random_state ensures reproducible results.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((11712,), (2928,), (11712,), (2928,))

# %%
# Vectorizing Text Data with TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english')

# %%
# Transforming Text Data into TF-IDF Feature Vectors
# fit_transform on the training set and transform the test set

X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
# Grid Search with Cross-Validation (HalvingGridSearch)

def grid_search(model, parameters):
    """
    Performs a halving grid search over 'parameters' for the given 'model'
    using 5-fold cross-validation. Optimizes the 'f1_weighted' score.
    
    Parameters:
    -----------
    model : estimator
        The base estimator to be optimized (e.g., BernoulliNB()).
    parameters : dict
        Dictionary of hyperparameters to search, e.g., {'alpha': [0.1, 0.5, 1.0]}.

    Returns:
    --------
    grid : HalvingGridSearchCV object
        The fitted HalvingGridSearchCV instance, which contains best_score_ 
        and best_params_ among other attributes.
    """
    
    grid = HalvingGridSearchCV(
        estimator=model,
        param_grid=parameters,
        factor=2,
        cv=5,
        scoring='f1_weighted',
        random_state=42,
        error_score=0
    )
    
    # Fit the grid to the training data
    grid.fit(X_train, y_train)
    
    print("Best Score :", grid.best_score_)
    print("Best Parameters :", grid.best_params_)
    
    # return the fitted grid for access to grid.best_estimator_
    return grid

# %%
# Initializing Naive Bayes models
BNB_model = BernoulliNB()
GNB_model = GaussianNB()
MNB_model = MultinomialNB()
CNB_model = ComplementNB()
NB_param = {}
#NB_param = {'alpha': [0.01, 0.1, 0.5, 1.0, 2.0]}

# %%
# Performing grid search to find the best parameters for each model
grid_search(BNB_model,NB_param)
# Out:
# Best Score :  0.6817561083854151
# Best parameters :  {}

# %%
# Performing grid search to find the best parameters for each model
grid_search(MNB_model,NB_param)
# Out:
# Best Score :  0.5918885659802978
# Best parameters :  {}

# %%
# Running grid search to find the best parameters for each model
grid_search(CNB_model,NB_param)
# Out:
# Best Score :  0.7338606511487076
# Best parameters :  {}

# %%
# GaussianNB requires dense matrix, converting X_train to array for compatibility
grid2 = HalvingGridSearchCV(estimator = GNB_model, param_grid=NB_param,factor = 2, cv = 5, 
                               scoring = 'f1_weighted',random_state=42,error_score = 0)

# Fitting the model to the training data
grid2.fit(X_train.toarray(), y_train) 
print('Best Score : ',grid2.best_score_)
print('Best parameters : ')
print(grid2.best_params_)
# Out:
# Best Score :  0.5315256824156318
# Best parameters :
# {}

# %%
BNB_model = BernoulliNB()
CNB_model = ComplementNB()

# %%
# Evaluating Bernoulli and Complement NB models on test data
models = [ BNB_model, CNB_model]

# %%
accuracy_scores = []
f1_scores = []

# %%
# Model Evaluation and Comparison
for model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    acc = accuracy_score(y_test,y_pred)
    accuracy_scores.append(acc)
    
    f1 = f1_score(y_test,y_pred,average='weighted')
    f1_scores.append(f1)
    
    print(model)
    print()
    print(classification_report(y_test,y_pred,labels = model.classes_))
    print()
    ConfusionMatrixDisplay.from_predictions(y_test,y_pred,labels = model.classes_)
    print()
# Out:
# BernoulliNB()
#
#               precision    recall  f1-score   support
#
#     negative       0.73      0.96      0.83      1837
#      neutral       0.61      0.33      0.43       589
#     positive       0.86      0.30      0.44       465
#
#     accuracy                           0.73      2891
#    macro avg       0.73      0.53      0.57      2891
# weighted avg       0.73      0.73      0.69      2891
#
#
#
# ComplementNB()
#
#               precision    recall  f1-score   support
#
#     negative       0.80      0.93      0.86      1837
#      neutral       0.63      0.39      0.48       589
#     positive       0.73      0.59      0.65       465
#
#     accuracy                           0.77      2891
#    macro avg       0.72      0.64      0.66      2891
# weighted avg       0.75      0.77      0.75      2891

# %%
accuracy_scores
# Out:
# [0.7277758561051539, 0.7672085783465928]

# %%
f1_scores
# Out:
# [0.6884928825928636, 0.7494418727239313]

# %%
# Define classifier models for comparison
clf_model = ['Bernoulli NB', 'Complement NB']

# %%
# Plotting the accuracy scores and F1 scores for the classifier models
plt.plot(clf_model,accuracy_scores,label='Accuracy Score')
plt.plot(clf_model,f1_scores,label='F1 Score')

# Setting the plot labels and title for clarity
plt.xlabel('Model')
plt.ylabel('Value')
plt.title('Final Model Comparison')

# Adding a legend to differentiate between the scores and rotating x-axis labels for readability
plt.legend()
plt.xticks(rotation=90);

# %%
print(X_train.shape, y_train.shape)
# Out:
# (11561, 11250) (11561,)

# %%
from sklearn.model_selection import cross_val_score

# Using the ComplementNB model as it performed better
model = ComplementNB()

# Perform 5-fold cross-validation and print the accuracy for each fold
cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')
print("CV Scores: ", cv_scores)
print("Average CV Score: ", cv_scores.mean())
# Out:
# CV Scores:  [0.74232598 0.74307958 0.74567474 0.75735294 0.74740484]
# Average CV Score:  0.7471676188595526

# %%
# Issues running ROC-AUC curve scripts
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score
import numpy as np

# df['airline_sentiment'] contains 'positive', 'negative', 'neutral' labels
X = df['text'] 
y = df['airline_sentiment']  # target labels

# Binarize the output labels for ROC computation
y_bin = label_binarize(y, classes=['negative', 'neutral', 'positive'])
n_classes = y_bin.shape[1]

# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)
y_train_bin, y_test_bin = train_test_split(y_bin, test_size=0.2, random_state=11)

# Vectorizing the text
vectorizer = TfidfVectorizer(stop_words='english')
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)

# Train the MultinomialNB model
model = MultinomialNB()
model.fit(X_train_vect, y_train)
# Out:
# MultinomialNB()

# %%
# Predict probabilities
y_score = model.predict_proba(X_test_vect)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve for each class
for i in range(n_classes):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC for class {i}')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# # Interpretting Model Validation for confusion matrix, accuracy score, ROC-AUC curves, and k-fold cross validation.
#
# In the evaluation of four Naive Bayes models through grid search, the Complement Naive Bayes emerged as the best-performing model. This assessment considers various metrics, including precision, recall, F1-score, accuracy, cross-validation scores, and ROC-AUC curves.
#
# The Complement Naive Bayes model showed a weighted average F1-score of 0.75, an accuracy of 0.77, a precision of 0.80 for negative sentiments, and a recall of 0.93 for the same. These scores indicate a robust ability to correctly identify negative sentiments while maintaining a reasonable performance on positive ones, with a precision of 0.73 and a recall of 0.59.
#
# The cross-validation scores with five folds reinforce the model's consistency, yielding an average accuracy of around 0.75. This suggests that the model's predictive power is stable across different subsets of the dataset.
#
# The ROC curves, which plot the true positive rate against the false positive rate, provide a visual affirmation of the model's effectiveness. The curve for the best model significantly surpasses the diagonal reference line, which represents random guessing, indicating a strong discriminatory ability.
#
# While all four Naive Bayes algorithms — Bernoulli, Gaussian, Multinomial, and Complement — were considered, the Complement Naive Bayes model's superior performance in precision, recall, and F1-scores across all classes, combined with robust cross-validation results, make it the preferable choice for this sentiment analysis task.

# %% [markdown]
# # Interpret Results in terms of questions asked
#
# The Naive Bayes classifier, particularly the Complement Naive Bayes variant, has demonstrated its capacity to effectively classify tweets into positive, negative, or neutral sentiments. This answers the first question affirmatively: the classifier can indeed distinguish among different sentiment classes with precision. The model’s high accuracy score, particularly in identifying negative sentiments, underlines its ability to leverage the probabilistic nature of the Naive Bayes algorithm for sentiment analysis.
#
# As for the second question, the performance of the Naive Bayes classifier suggests that specific keywords and phrases play a significant role in determining sentiment classification. This is supported by the weighted F1-scores, which consider both precision and recall. High precision in negative and positive classifications indicates that certain terms strongly associated with these sentiments are likely present in the dataset and effectively captured by the model. Moreover, the model's recall score for negative sentiment, being quite high, implies that it can reliably identify tweets with negative keywords.
#
# Overall, these findings suggest that the Naive Bayes classifier, with its simplicity and probabilistic foundation, is a reliable tool for parsing through text data and extracting sentiment. It shows potential for further application in social media monitoring, customer service enhancement, and targeted marketing strategies, given its ability to understand customer feedback and sentiment trends. This could be particularly useful for airlines to gauge public perception and improve their service quality by focusing on the negative aspects highlighted in customer feedback.

# %% [markdown]
# # References:
# Eight, F. (2019, October 16). Twitter us airline sentiment. Kaggle. https://www.kaggle.com/datasets/crowdflower/twitter-airline-sentiment/data
